# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.alert import Alert

from bs4 import BeautifulSoup

# %%
# Before you process this code, you must download chromedriver : https://chromedriver.chromium.org/downloads
# Enter your chromedriver path into below line

chrome_path = "your chromedriver path."
driver = webdriver.Chrome(executable_path = chrome_path)


url = 'https://everytime.kr/' 
driver.get(url)

# %%
driver.find_element_by_css_selector("body > aside > div.login > a.button.login").click()

# enter your Id and password
ID = input("Enter your ID") 
PW = input("Enter your password")


my_id = driver.find_element_by_css_selector("#container > form > p:nth-child(1) > input")
my_id.send_keys(ID)

my_ps = driver.find_element_by_css_selector("#container > form > p:nth-child(2) > input")
my_ps.send_keys(PW)

my_ps.submit()

time.sleep(3)

# %%
html = driver.page_source
soup = BeautifulSoup(html)
body = driver.find_element_by_tag_name('html')

# You can browse variable board
# The address may change later

freeboard     = '#submenu > div > div:nth-child(2) > ul > li:nth-child(1) > a'
secretboard   = '#submenu > div > div:nth-child(2) > ul > li:nth-child(2) > a'
raduatedboard = '#submenu > div > div:nth-child(2) > ul > li:nth-child(3) > a'
freshmanboard = '#submenu > div > div:nth-child(2) > ul > li:nth-child(4) > a'

nurseboard    = '#submenu > div > div:nth-child(7) > ul > li:nth-child(6) > a'

# %%
# This code for remove the Ads

driver.find_element_by_css_selector(freshmanboard).click()
time.sleep(5)
driver.find_element_by_css_selector('#sheet > ul > li.none > a').click()

# %%
# 자유게시판, 새내기게시판 번갈아가기

# 16번째 주소부터 4번째 주소까지의 게시글에 대한 따봉

freelist = [16,15,14,13,12,11,10,9,8,7,6,5,4]
freshlist = [16,15,14,13,12,11,10,9,8,7,6,5,4]

# 따봉속도조절
pause_time = 0.6
circle = 0


# circle을 이용하여 반복횟수 조절
# while circle < 5:


# 무한반복
while True:
    # 자유게시판
    driver.find_element_by_css_selector(freeboard).click()
    time.sleep(4*pause_time)
    
    for article_num in freelist:
        time.sleep(pause_time)
        
        try:
            good = 0
            length = 0

            time.sleep(1)
            good_tag = '#container > div.wrap.articles > article:nth-child('+ str(article_num) +') > a > ul > li.vote'
            good = int(driver.find_element_by_css_selector(good_tag).text)

            length_tag = '#container > div.wrap.articles > article:nth-child('+ str(article_num) +') > a > ul > li.comment'
            length = int(driver.find_element_by_css_selector(length_tag).text)

            if good == 0:
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a > ul > li.vote').click()
                time.sleep(pause_time)
                Alert(driver).accept()
                time.sleep(pause_time)
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a').click()
            else:
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a').click()



            time.sleep(6*pause_time)


            html = driver.page_source
            soup = BeautifulSoup(html)
            body = driver.find_element_by_tag_name('html')


            if length == 0:
                driver.back()

            else:

                for k in range(1,length + 1):
                    comment_loc = '#container > div.wrap.articles > article > div > article:nth-child('+ str(k) +') > p'
                    comment = driver.find_element_by_css_selector(comment_loc).text
                    
                    if comment == '삭제된 댓글입니다.':
                        pass
                    
                    else:
                        
                        good_num = driver.find_element_by_css_selector('#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul.status.commentvotestatus > li').text

                        if good_num == "":
                            goodloc = '#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul:nth-child(3) > li.commentvote'

                            driver.find_element_by_css_selector(goodloc).click()
                            time.sleep(pause_time/2)
                            Alert(driver).accept()
                            time.sleep(pause_time/2)

                        else:
                            continue

                driver.back()
                time.sleep(2*pause_time)
                
        except:
            continue

    # 새내기게시판
    driver.find_element_by_css_selector(freshmanboard).click()
    driver.refresh()
    time.sleep(4*pause_time)


    for article_num in freshlist:
        
        try:
            good = 0
            length = 0

            time.sleep(1)
            good_tag = '#container > div.wrap.articles > article:nth-child('+ str(article_num) +') > a > ul > li.vote'
            good = int(driver.find_element_by_css_selector(good_tag).text)

            length_tag = '#container > div.wrap.articles > article:nth-child('+ str(article_num) +') > a > ul > li.comment'
            length = int(driver.find_element_by_css_selector(length_tag).text)

            if good == 0:
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a > ul > li.vote').click()
                time.sleep(pause_time)
                Alert(driver).accept()
                time.sleep(pause_time)
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a').click()
            else:
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a').click()



            time.sleep(6*pause_time)


            html = driver.page_source
            soup = BeautifulSoup(html)
            body = driver.find_element_by_tag_name('html')


            if length == 0:
                driver.back()
              

            else:

                for k in range(1,length + 1):
                    comment_loc = '#container > div.wrap.articles > article > div > article:nth-child('+ str(k) +') > p'
                    comment = driver.find_element_by_css_selector(comment_loc).text
                    
                    if comment == '삭제된 댓글입니다.':
                        pass
                    
                    else:
                    
                        good_num = driver.find_element_by_css_selector('#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul.status.commentvotestatus > li').text

                        if good_num == "":
                            goodloc = '#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul:nth-child(3) > li.commentvote'

                            driver.find_element_by_css_selector(goodloc).click()
                            time.sleep(pause_time/2)
                            Alert(driver).accept()
                            time.sleep(pause_time/2)

                        else:
                            continue

                driver.back()
                time.sleep(2*pause_time)
                
        except:
            continue

    driver.refresh()
    time.sleep(2*pause_time)
    
    circle += 1
    print(circle)

# %%
# 자유게시판 단타
# 게시판에 들어간다음 사용하면 된다.

pause_time = 0.5

good = 0
length = 0


html = driver.page_source
soup = BeautifulSoup(html)
body = driver.find_element_by_tag_name('html')



length_tag = '#container > div.wrap.articles > article > a > ul:nth-child(7) > li.comment'
length = int(driver.find_element_by_css_selector(length_tag).text)


if length == 0:
    driver.back()

else:

    for k in range(1,length + 1):
        comment_loc = '#container > div.wrap.articles > article > div > article:nth-child('+ str(k) +') > p'
        comment = driver.find_element_by_css_selector(comment_loc).text

        if comment == '삭제된 댓글입니다.':
            pass

        else:

            good_num = driver.find_element_by_css_selector('#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul.status.commentvotestatus > li').text

            if good_num == "":
                goodloc = '#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul:nth-child(3) > li.commentvote'

                driver.find_element_by_css_selector(goodloc).click()
                time.sleep(pause_time/2)
                Alert(driver).accept()
                time.sleep(pause_time/2)

            else:
                continue

    driver.back()
    time.sleep(2*pause_time)

# %%
# 새내기, 비밀, 간호 단타
# 게시판에 들어간다음 사용하면 된다.

pause_time = 0.5

good = 0
length = 0

length_tag = '#container > div.wrap.articles > article > a > ul:nth-child(6) > li.comment'
length = int(driver.find_element_by_css_selector(length_tag).text)


if length == 0:
    driver.back()


else:
    for k in range(1,length + 1):
        comment_loc = '#container > div.wrap.articles > article > div > article:nth-child('+ str(k) +') > p'
        comment = driver.find_element_by_css_selector(comment_loc).text

        if comment == '삭제된 댓글입니다.':
            pass

        else:

            good_num = driver.find_element_by_css_selector('#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul.status.commentvotestatus > li').text

            if good_num == "":
                goodloc = '#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul:nth-child(3) > li.commentvote'

                driver.find_element_by_css_selector(goodloc).click()
                time.sleep(pause_time/2)
                Alert(driver).accept()
                time.sleep(pause_time/2)

            else:
                continue

    driver.back()
    time.sleep(2*pause_time)

# %%
# 자유 장타
# 게시판에 들어간다음 사용하면 된다.

pause_time = 0.5
circle = 0
boradlist = [16,15,14,13,12,11,10,9,8,7,6,5,4]

while circle < 2:
   
    for article_num in freelist:
        time.sleep(pause_time)
        
        try:
            good = 0
            length = 0

            time.sleep(1)
            good_tag = '#container > div.wrap.articles > article:nth-child('+ str(article_num) +') > a > ul > li.vote'
            good = int(driver.find_element_by_css_selector(good_tag).text)

            length_tag = '#container > div.wrap.articles > article:nth-child('+ str(article_num) +') > a > ul > li.comment'
            length = int(driver.find_element_by_css_selector(length_tag).text)

            if good == 0:
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a > ul > li.vote').click()
                time.sleep(pause_time)
                Alert(driver).accept()
                time.sleep(pause_time)
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a').click()
            else:
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a').click()



            time.sleep(6*pause_time)


            html = driver.page_source
            soup = BeautifulSoup(html)
            body = driver.find_element_by_tag_name('html')


            if length == 0:
                driver.back()

            else:

                for k in range(1,length + 1):
                    comment_loc = '#container > div.wrap.articles > article > div > article:nth-child('+ str(k) +') > p'
                    comment = driver.find_element_by_css_selector(comment_loc).text
                    
                    if comment == '삭제된 댓글입니다.':
                        pass
                    
                    else:
                        
                        good_num = driver.find_element_by_css_selector('#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul.status.commentvotestatus > li').text

                        if good_num == "":
                            goodloc = '#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul:nth-child(3) > li.commentvote'

                            driver.find_element_by_css_selector(goodloc).click()
                            time.sleep(pause_time/2)
                            Alert(driver).accept()
                            time.sleep(pause_time/2)

                        else:
                            continue

                driver.back()
                time.sleep(2*pause_time)
                
        except:
            continue
        
    circle += 1

# %%
# 새내기, 간호, 비밀 장타
# 게시판에 들어간다음 사용하면 된다.

boradlist = [16,15,14,13,12,11,10,9,8,7,6,5,4]

pause_time = 0.5
circle = 0

while circle < 2:

    for article_num in boradlist:
        time.sleep(pause_time)
        
        try:
            good = 0
            length = 0

            time.sleep(1)
            good_tag = '#container > div.wrap.articles > article:nth-child('+ str(article_num) +') > a > ul > li.vote'
            good = int(driver.find_element_by_css_selector(good_tag).text)

            length_tag = '#container > div.wrap.articles > article:nth-child('+ str(article_num) +') > a > ul > li.comment'
            length = int(driver.find_element_by_css_selector(length_tag).text)

            if good == 0:
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a > ul > li.vote').click()
                time.sleep(pause_time)
                Alert(driver).accept()
                time.sleep(pause_time)
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a').click()
            else:
                driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child(' + str(article_num) + ') > a').click()



            time.sleep(6*pause_time)


            html = driver.page_source
            soup = BeautifulSoup(html)
            body = driver.find_element_by_tag_name('html')


            if length == 0:
                driver.back()

            else:

                for k in range(1,length + 1):
                    comment_loc = '#container > div.wrap.articles > article > div > article:nth-child('+ str(k) +') > p'
                    comment = driver.find_element_by_css_selector(comment_loc).text
                    
                    if comment == '삭제된 댓글입니다.':
                        pass
                    
                    else:
                        
                        good_num = driver.find_element_by_css_selector('#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul.status.commentvotestatus > li').text

                        if good_num == "":
                            goodloc = '#container > div.wrap.articles > article > div > article:nth-child(' + str(k) + ') > ul:nth-child(3) > li.commentvote'

                            driver.find_element_by_css_selector(goodloc).click()
                            time.sleep(pause_time/2)
                            Alert(driver).accept()
                            time.sleep(pause_time/2)

                        else:
                            continue

                driver.back()
                time.sleep(2*pause_time)
                
        except:
            continue

    driver.refresh()
    time.sleep(2*pause_time)
    
    circle += 1
